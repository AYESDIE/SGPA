# %%
import numpy
import plotly

# %%
mean_values = numpy.load("../assets/mean_points_emb.npy")

# %%
mean_values.shape
# Out:
# (6, 1024, 3)

# %%
mean_values[1].shape
# Out:
# (1024, 3)

# %%
idx = 1
x = mean_values[idx, :, 0]
y = mean_values[idx, :, 1]
z = mean_values[idx, :, 2]
fig = plotly.graph_objects.Figure(data=[plotly.graph_objects.Scatter3d(x=x, y=y, z=z,
                                   mode='markers')])
fig.show()

# %%
!

# %%
# !pip install nbformat
